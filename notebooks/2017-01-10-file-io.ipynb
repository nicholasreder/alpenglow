# %%
import sys 
sys.path.append('..')

# %%
import alpenglow.files as af

# %%
my_file = af.DCIMGFile('../data/phantom/000000.dcimg')

# %%
f1000 = my_file.get_frame(1000)
# Out:
# ../alpenglow/files.py:93: VisibleDeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   self._info['bytes_per_pixel']), ind]
# ../alpenglow/files.py:98: VisibleDeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   order='F')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.matshow(f1000, cmap='viridis')
